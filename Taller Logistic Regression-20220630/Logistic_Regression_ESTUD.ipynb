# %% [markdown]
# En este caso, llevaremos a cabo un recorrido exhaustivo de un problema de ciencia de datos de clasificación binaria. Nuestro objetivo es combinar las diversas técnicas de pre-modelado que hemos aprendido con la validación cruzada para afinar un modelo de regresión logística.
# Además, introducimos varias métricas (ROC/AUC) para evaluar el rendimiento de nuestro modelo de clasificación, que es intrínsecamente diferente de los anteriores modelos de regresión lineal que hemos encontrado. Este objetivo puede parecer un poco intimidante o técnico, pero al final del caso, todos estos términos deberían estar claros para usted.

# %%
### Load relevant packages
import pandas                  as pd
import numpy                   as np
import matplotlib.pyplot       as plt
import seaborn                 as sns
import os

from scipy import stats

# %matplotlib inline
plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Contexto

# %% [markdown]
# Los bancos comerciales tradicionales no solían basarse en modelos estadísticos para decidir si debían emitirse préstamos personales, aunque esto está cambiando rápidamente en la actualidad. Usted es un científico de datos que trabaja en un banco comercial moderno. Su equipo de ciencia de datos ya ha construido modelos de regresión sencillos para predecir la probabilidad de que esos préstamos sean incumplidos. Sin embargo, ha observado que muchos de estos modelos funcionan mucho peor en producción que en las pruebas.

# %% [markdown]
# Su tarea consiste en crear un modelo de probabilidad de incumplimiento que le resulte cómodo poner en producción.

# %% [markdown]
# El conjunto de datos contiene los detalles de 5.000 solicitudes de préstamo que han sido emitidas previamente por su banco. Para cada préstamo, también se dispone del estado final del mismo (es decir, si el préstamo ha entrado en mora):
# El archivo "loan_light.csv" contiene los detalles de 5000 préstamos
# El archivo "loan_param.xlsx" contiene la descripción de cada covariable
# El caso se desarrollará de la siguiente manera: 1) realizará una exploración de los datos para determinar las transformaciones adecuadas de las variables; 2) ajustará algunos modelos simples; 3) aprenderá sobre la validación cruzada y la utilizará para seleccionar el mejor modelo simple; y finalmente 4) construirá responsablemente modelos más complejos utilizando la validación cruzada.

# %% [markdown]
# ## Ejericios

# %% [markdown]
# 1. Cargue los datos y el diccionario de variables.

# %%
#Cargar csv
df = pd.read_csv("loan_light.csv")


#pista para diccionario
df_description = pd.read_excel('loan_param.xlsx').dropna()
df_description.style.set_properties(subset=['Description'], **{'width': '1000px'})
# Out:
# <style type="text/css">
# #T_0a723_row0_col1, #T_0a723_row1_col1, #T_0a723_row2_col1, #T_0a723_row3_col1, #T_0a723_row4_col1, #T_0a723_row5_col1, #T_0a723_row6_col1, #T_0a723_row7_col1, #T_0a723_row8_col1, #T_0a723_row9_col1, #T_0a723_row10_col1, #T_0a723_row11_col1, #T_0a723_row12_col1, #T_0a723_row13_col1, #T_0a723_row14_col1, #T_0a723_row15_col1, #T_0a723_row16_col1, #T_0a723_row17_col1, #T_0a723_row18_col1, #T_0a723_row19_col1, #T_0a723_row20_col1 {
#   width: 1000px;
# }
# </style>
# <table id="T_0a723">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a723_level0_col0" class="col_heading level0 col0" >BrowseNotesFile</th>
#       <th id="T_0a723_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a723_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a723_row0_col0" class="data row0 col0" >loanAmnt</td>
#       <td id="T_0a723_row0_col1" class="data row0 col1" >The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a723_row1_col0" class="data row1 col0" >annualInc</td>
#       <td id="T_0a723_row1_col1" class="data row1 col1" >The self-reported annual income provided by the borrower during registration.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a723_row2_col0" class="data row2 col0" >application_type</td>
#       <td id="T_0a723_row2_col1" class="data row2 col1" >Indicates whether the loan is an individual application or a joint application with two co-borrowers</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a723_row3_col0" class="data row3 col0" >avg_cur_bal</td>
#       <td id="T_0a723_row3_col1" class="data row3 col1" >Average current balance of all accounts</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0a723_row4_col0" class="data row4 col0" >chargeoff_within_12_mths</td>
#       <td id="T_0a723_row4_col1" class="data row4 col1" >Number of charge-offs within 12 months</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0a723_row5_col0" class="data row5 col0" >delinq2Yrs</td>
#       <td id="T_0a723_row5_col1" class="data row5 col1" >The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0a723_row6_col0" class="data row6 col0" >dti</td>
#       <td id="T_0a723_row6_col1" class="data row6 col1" >A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0a723_row7_col0" class="data row7 col0" >emp_length</td>
#       <td id="T_0a723_row7_col1" class="data row7 col1" >Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0a723_row8_col0" class="data row8 col0" >grade</td>
#       <td id="T_0a723_row8_col1" class="data row8 col1" >LC assigned loan grade</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0a723_row9_col0" class="data row9 col0" >homeOwnership</td>
#       <td id="T_0a723_row9_col1" class="data row9 col1" >The home ownership status provided by the borrower during registration. Our values are: RENT, OWN, MORTGAGE, OTHER.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0a723_row10_col0" class="data row10 col0" >inq_last_12m</td>
#       <td id="T_0a723_row10_col1" class="data row10 col1" >Number of credit inquiries in past 12 months</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0a723_row11_col0" class="data row11 col0" >installment</td>
#       <td id="T_0a723_row11_col1" class="data row11 col1" >The monthly payment owed by the borrower if the loan originates.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0a723_row12_col0" class="data row12 col0" >job</td>
#       <td id="T_0a723_row12_col1" class="data row12 col1" >Job Description</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0a723_row13_col0" class="data row13 col0" >loanAmnt</td>
#       <td id="T_0a723_row13_col1" class="data row13 col1" >The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0a723_row14_col0" class="data row14 col0" >loanDefault</td>
#       <td id="T_0a723_row14_col1" class="data row14 col1" >0: Loan was uptimated paid in full. 1: A default even occurred</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0a723_row15_col0" class="data row15 col0" >mortAcc</td>
#       <td id="T_0a723_row15_col1" class="data row15 col1" >Number of mortgage accounts.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0a723_row16_col0" class="data row16 col0" >num_tl_90g_dpd_24m</td>
#       <td id="T_0a723_row16_col1" class="data row16 col1" >Number of accounts 90 or more days past due in last 24 months</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0a723_row17_col0" class="data row17 col0" >pub_rec_bankruptcies</td>
#       <td id="T_0a723_row17_col1" class="data row17 col1" >Number of public record bankruptcies</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0a723_row18_col0" class="data row18 col0" >purpose</td>
#       <td id="T_0a723_row18_col1" class="data row18 col1" >A category provided by the borrower for the loan request. </td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0a723_row19_col0" class="data row19 col0" >term</td>
#       <td id="T_0a723_row19_col1" class="data row19 col1" >The number of payments on the loan. Values are in months and can be either 36 or 60.</td>
#     </tr>
#     <tr>
#       <th id="T_0a723_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0a723_row20_col0" class="data row20 col0" >Year</td>
#       <td id="T_0a723_row20_col1" class="data row20 col1" >Year of Issue of the loan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 2. Cree un gráfico de barras que muestre el número de préstamos que han entrado en mora y los que no.

# %%
df.head()
# Out:
#    annual_inc application_type  avg_cur_bal  chargeoff_within_12_mths  \
# 0     80000.0       Individual       6746.0                       0.0
# 1     60000.0       Individual      13623.0                       0.0
# 2     78000.0       Individual      11011.0                       0.0
# 3     62000.0       Individual       9679.0                       0.0
# 4     49000.0       Individual       4925.0                       0.0
#
#    delinq_2yrs    dti  emp_length grade  inq_last_12m  installment  ...  \
# 0          0.0  15.12          10     B           1.0       743.75  ...
# 1          0.0  12.32           7     D           0.0       286.73  ...
# 2          0.0  25.00           1     D           6.0       869.66  ...
# 3          0.0  22.32           9     D           7.0       713.96  ...
# 4          0.0  32.43          10     D           0.0       366.51  ...
#
#    num_actv_bc_tl  pub_rec_bankruptcies  home_ownership term  mort_acc  \
# 0             1.0                   0.0             OWN   36       0.0
# 1             3.0                   0.0        MORTGAGE   60       1.0
# 2             4.0                   0.0        MORTGAGE   60       3.0
# 3             2.0                   0.0            RENT   36       4.0
# 4             4.0                   0.0            RENT   36       0.0
#
#    num_tl_90g_dpd_24m             purpose  year  loan_default        job
# 0                 0.0  debt_consolidation  2016             1  principal
# 1                 0.0         credit_card  2017             0      other
# 2                 0.0  debt_consolidation  2015             0    analyst
# 3                 0.0  debt_consolidation  2017             1      other
# 4                 0.0  debt_consolidation  2017             1     driver
#
# [5 rows x 21 columns]

# %%
dfLoan = pd.DataFrame(df['loan_default'].value_counts()).reset_index()
dfLoan
# Out:
#    index  loan_default
# 0      0          3853
# 1      1          1147

# %%
sns.barplot(x = 'index',y = 'loan_default', data = dfLoan) ## 0 no estan en mora , 1 si esta en mora
# Out:
# <AxesSubplot:xlabel='index', ylabel='loan_default'>

# %% [markdown]
# 3. Crea un histograma de los ingresos anuales y describelo.

# %%
plt.hist(df['annual_inc'], label = ['ingresos'])
plt.legend()

# %% [markdown]
# ## La mayor concentracion de personas que solicitan creditos o prestamos tienen ingresos menores a 100000 dolares

# %% [markdown]
# 4. Explora la asociación entre los ingresos anuales y la cuota mensual (scatterplot).

# %%
sns.scatterplot(data = df, x = 'annual_inc', y = 'installment', hue = 'loan_default', palette = 'colorblind')
# Out:
# <AxesSubplot:xlabel='annual_inc', ylabel='installment'>

# %% [markdown]
# ## Se puede apreciar que la mayoria de los solicitantes de prestamos tienen una cuota que no excede mas del 15% de sus ingresos. Sin embargo existen valores atipicos de cuotas muy altas en personas con bajos ingresos y cuotas muy bajas en personas con altos ingresos

# %% [markdown]
# 5. Visualice la matriz de correlación en todas las características numéricas utilizando el comando sns.heatmap()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   annual_inc                5000 non-null   float64
#  1   application_type          5000 non-null   object
#  2   avg_cur_bal               5000 non-null   float64
#  3   chargeoff_within_12_mths  5000 non-null   float64
#  4   delinq_2yrs               5000 non-null   float64
#  5   dti                       5000 non-null   float64
#  6   emp_length                5000 non-null   int64
#  7   grade                     5000 non-null   object
#  8   inq_last_12m              5000 non-null   float64
#  9   installment               5000 non-null   float64
#  10  loan_amnt                 5000 non-null   int64
#  11  num_actv_bc_tl            5000 non-null   float64
#  12  pub_rec_bankruptcies      5000 non-null   float64
#  13  home_ownership            5000 non-null   object
#  14  term                      5000 non-null   int64
#  15  mort_acc                  5000 non-null   float64
#  16  num_tl_90g_dpd_24m        5000 non-null   float64
#  17  purpose                   5000 non-null   object
#  18  year                      5000 non-null   int64
#  19  loan_default              5000 non-null   int64
#  20  job                       5000 non-null   object
# dtypes: float64(11), int64(5), object(5)
# memory usage: 820.4+ KB

# %%
lista_numericas = ['annual_inc','avg_cur_bal','chargeoff_within_12_mths','delinq_2yrs','dti','emp_length','inq_last_12m',
                  'installment','loan_amnt','num_actv_bc_tl','pub_rec_bankruptcies','term','mort_acc','num_tl_90g_dpd_24m',
                  'year','loan_default']

corr = df[lista_numericas].corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, cmap='Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 6. Cree un modelo básico de regresión logística para predecir el incumplimiento del préstamo con una sola característica: install_income. Llame a este modelo modelo1. Utilice una división 70/30 de los datos entre el entrenamiento y la prueba.

# %%
x =df['installment']
y =

# %% [markdown]
# 7. Trace la curva [ROC](https://towardsdatascience.com/understanding-auc-roc-curve-68b2303cc9c5) del modelo1 y encuentre el área bajo la curva.

# %%
#pista
from sklearn import metrics
y_pred_prob = model1.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_prob)
auc = metrics.roc_auc_score(y_test, y_pred_prob)

plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# 8. Cree un modelo básico de regresión logística para predecir el incumplimiento del préstamo solo con las caracteristicas numericas. Llame a este modelo modelo2. Utilice una división 70/30 de los datos entre el entrenamiento y la prueba.

# %% [markdown]
# 9. Trace la curva ROC del modelo2 y encuentre el área bajo la curva. Es mejor modelo?

# %% [markdown]
# 10. Cree un modelo básico de regresión logística para predecir el incumplimiento del préstamo con las caracteristicas numericas, y agregue algunas categoricas (get_dummies()). Llame a este modelo modelo3. Utilice una división 70/30 de los datos entre el entrenamiento y la prueba.

# %% [markdown]
# 11. Trace la curva ROC del modelo3, y encuentre el área bajo la curva. Mejora el modelo agregando variables categoricas?
